# %%
import datacube
dc = datacube.Datacube()

# %%
dc.list_products()
# Out:
#                 name                                        description  \
# id
# 213        LC08_caea  Landsat 8 L1TP Canadian Albers Equal Area, 100...
# 214    LC08_caea_30m  Landsat 8 L1TP Canadian Albers Equal Area, 90k...
# 216  LC08_caea_30m_1  Landsat 8 L1TP Canadian Albers Equal Area, 90k...
# 217  LC08_caea_30m_2  Landsat 8 L1TP Canadian Albers Equal Area, 90k...
# 204       LC08_scene         Landsat 8 OLI-TIRS Level1 Collection1 L1TP
# 212        LE07_caea                              Landsat 7 L1TP netcdf
# 205       LE07_scene            Landsat 7 ETM Collection 1 Level 1 L1TP
# 210        LM03_caea  Landsat 3 MSS L1TP Canadian Albers Equal Area,...
# 215    LM03_caea_30m  Landsat 3 MSS L1TP Canadian Albers Equal Area,...
# 208       LM03_scene            Landsat 3 MSS Level 1 Collection 1 L1TP
# 209        LM05_caea  Landsat 5 MSS L1TP Canadian Albers Equal Area,...
# 206       LM05_scene            Landsat 5 MSS Level 1 Collection 1 L1TP
# ...

# %%
#meas = dc.list_measurements()

# %%
#type(meas)

# %%
#meas

# %%
dc.find_datasets(product = 'LC08_caea_30m_2')
# Out:
# [Dataset <id=cc10fcfb-a355-4dc8-bf2b-e7b353c16d1d type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_9__5__20150916155645790119.nc>,
#  Dataset <id=a9114e82-889e-4b1a-a5e0-b0938a06b8a8 type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_9__6__20150916155645790119.nc>,
#  Dataset <id=1ae045ed-e9a0-440e-8c8c-bbceff420057 type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_10__5__20150916155645790119.nc>,
#  Dataset <id=2d197948-a52a-4718-81be-7b8678139e6c type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_10__6__20150916155645790119.nc>,
#  Dataset <id=bac9b3be-5597-4203-918c-bcf98388727c type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_8__6__20150916155645790119.nc>,
#  Dataset <id=5480d97c-07b6-421f-91a7-6201381a1839 type=LC08_caea_30m_2 location=/data/datacube/repository/caea_30m/LC08_caea_30m_2_8__5__20150916155645790119.nc>,
# ...

# %%
data = dc.load(product="LC08_caea_30m_2", time = ('2015-07', '2015-08'))

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 1, x: 10190, y: 10254)
# Coordinates:
#   * time             (time) datetime64[ns] 2015-07-09T18:54:21.313685
#   * y                (y) float64 1.292e+06 1.292e+06 1.292e+06 1.292e+06 ...
#   * x                (x) float64 -1.565e+06 -1.565e+06 -1.565e+06 -1.565e+06 ...
# Data variables:
#     coastal_aerosol  (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     blue             (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     green            (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     red              (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     nir              (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     swir1            (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     swir2            (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
#     panchromatic     (time, y, x) int16 32767 32767 32767 32767 32767 32767 ...
# ...
