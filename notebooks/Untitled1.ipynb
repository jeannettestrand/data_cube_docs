# %%
import datacube
from datacube.storage.masking import mask_invalid_data
from datacube.api.query import Query
dc = datacube.Datacube()

# %%
dc.list_products()
# Out:
#            name                                        description instrument  \
# id
# 213   LC08_caea  Landsat 8 L1TP Canadian Albers Equal Area, 100...   OLI_TIRS
# 204  LC08_scene         Landsat 8 OLI-TIRS Level1 Collection1 L1TP   OLI_TIRS
# 212   LE07_caea                              Landsat 7 L1TP netcdf        ETM
# 205  LE07_scene            Landsat 7 ETM Collection 1 Level 1 L1TP        ETM
# 210   LM03_caea  Landsat 3 MSS L1TP Canadian Albers Equal Area,...        MSS
# 208  LM03_scene            Landsat 3 MSS Level 1 Collection 1 L1TP        MSS
# 209   LM05_caea  Landsat 5 MSS L1TP Canadian Albers Equal Area,...        MSS
# 206  LM05_scene            Landsat 5 MSS Level 1 Collection 1 L1TP        MSS
# 211   LT05_caea  Landsat 5 L1TP Canadian Albers Equal Area Proj...         TM
# 207  LT05_scene             Landsat 5 TM Level 1 Collection 1 L1TP         TM
#
#     product_type   lon   platform   lat   format  time          crs  \
# id
# 213         L1TP  None  LANDSAT_8  None   NetCDF  None  EPSG:102001
# 204         L1TP  None  LANDSAT_8  None  GeoTiff  None    EPSG:4326
# 212         L1TP  None  LANDSAT_7  None   NetCDF  None  EPSG:102001
# 205         L1TP  None  LANDSAT_7  None  GeoTiff  None    EPSG:4326
# 210         L1TP  None  LANDSAT_3  None   NetCDF  None  EPSG:102001
# 208         L1TP  None  LANDSAT_3  None  GeoTiff  None    EPSG:4326
# 209         L1TP  None  LANDSAT_5  None   NetCDF  None  EPSG:102001
# 206         L1TP  None  LANDSAT_5  None  GeoTiff  None    EPSG:4326
# 211         L1TP  None  LANDSAT_5  None   NetCDF  None  EPSG:102001
# 207         L1TP  None  LANDSAT_5  None  GeoTiff  None    EPSG:4326
#
#     resolution             tile_size     spatial_dimensions
# id
# 213  [25, -25]  [100000.0, 100000.0]                 (y, x)
# 204       None                  None  (latitude, longitude)
# 212  [-25, 25]  [100000.0, 100000.0]                 (y, x)
# 205       None                  None  (latitude, longitude)
# 210  [25, -25]  [100000.0, 100000.0]                 (y, x)
# 208       None                  None  (latitude, longitude)
# 209  [25, -25]  [100000.0, 100000.0]                 (y, x)
# 206       None                  None  (latitude, longitude)
# 211  [25, -25]  [100000.0, 100000.0]                 (y, x)
# 207       None                  None  (latitude, longitude)

# %%
dc.list_measurements()
# Out:
#                                               aliases  dtype  \
# product    measurement
# LC08_caea  coastal_aerosol  [band_1, coastal_aerosol]  int16
#            blue                        [band_2, blue]  int16
#            green                      [band_3, green]  int16
#            red                          [band_4, red]  int16
#            nir                          [band_5, nir]  int16
#            swir1                      [band_6, swir1]  int16
#            swir2                      [band_7, swir2]  int16
#            panchromatic        [band_8, panchromatic]  int16
#            cirrus                    [band_9, cirrus]  int16
#            lwir1                     [band_10, lwir1]  int16
#            lwir2                     [band_11, lwir2]  int16
#            quality                 [QUALITY, quality]  int16
# LC08_scene coastal_aerosol  [band_1, coastal_aerosol]  int16
#            blue                        [band_2, blue]  int16
#            green                      [band_3, green]  int16
#            red                          [band_4, red]  int16
#            nir                          [band_5, nir]  int16
#            swir1                      [band_6, swir1]  int16
#            swir2                      [band_7, swir2]  int16
#            panchromatic        [band_8, panchromatic]  int16
#            cirrus                    [band_9, cirrus]  int16
#            lwir1                     [band_10, lwir1]  int16
#            lwir2                     [band_11, lwir2]  int16
#            quality                 [QUALITY, quality]  int16
# LE07_caea  blue                        [band_1, blue]  int16
#            green                      [band_2, green]  int16
#            red                          [band_3, red]  int16
#            nir                          [band_4, nir]  int16
#            swir1                      [band_5, swir1]  int16
#            swir2                      [band_7, swir2]  int16
# ...                                               ...    ...
# LM03_caea  quality                 [QUALITY, quality]  int16
# LM03_scene green                      [band_4, green]  int16
#            red                          [band_5, red]  int16
#            nir1                        [band_6, nir1]  int16
#            nir2                        [band_7, nir2]  int16
#            quality                 [QUALITY, quality]  int16
# LM05_caea  green                      [band_1, green]  int16
#            red                          [band_2, red]  int16
#            nir1                        [band_3, nir1]  int16
#            nir2                        [band_4, nir2]  int16
#            quality                 [QUALITY, quality]  int16
# LM05_scene green                      [band_1, green]  int16
#            red                          [band_2, red]  int16
#            nir1                        [band_3, nir1]  int16
#            nir2                        [band_4, nir2]  int16
#            quality                 [QUALITY, quality]  int16
# LT05_caea  blue                        [band_1, blue]  int16
#            green                      [band_2, green]  int16
#            nir                          [band_4, red]  int16
#            red                          [band_3, nir]  int16
#            swir1                      [band_5, swir1]  int16
#            swir2                      [band_7, swir2]  int16
#            quality                 [QUALITY, quality]  int16
# LT05_scene blue                        [band_1, blue]  int16
#            green                      [band_2, green]  int16
#            nir                          [band_4, red]  int16
#            red                          [band_3, nir]  int16
#            swir1                      [band_5, swir1]  int16
#            swir2                      [band_7, swir2]  int16
#            quality                 [QUALITY, quality]  int16
#
#                                                              flags_definition  \
# product    measurement
# LC08_caea  coastal_aerosol                                                NaN
#            blue                                                           NaN
#            green                                                          NaN
#            red                                                            NaN
#            nir                                                            NaN
#            swir1                                                          NaN
#            swir2                                                          NaN
#            panchromatic                                                   NaN
#            cirrus                                                         NaN
#            lwir1                                                          NaN
#            lwir2                                                          NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LC08_scene coastal_aerosol                                                NaN
#            blue                                                           NaN
#            green                                                          NaN
#            red                                                            NaN
#            nir                                                            NaN
#            swir1                                                          NaN
#            swir2                                                          NaN
#            panchromatic                                                   NaN
#            cirrus                                                         NaN
#            lwir1                                                          NaN
#            lwir2                                                          NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LE07_caea  blue                                                           NaN
#            green                                                          NaN
#            red                                                            NaN
#            nir                                                            NaN
#            swir1                                                          NaN
#            swir2                                                          NaN
# ...                                                                       ...
# LM03_caea  quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LM03_scene green                                                          NaN
#            red                                                            NaN
#            nir1                                                           NaN
#            nir2                                                           NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LM05_caea  green                                                          NaN
#            red                                                            NaN
#            nir1                                                           NaN
#            nir2                                                           NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LM05_scene green                                                          NaN
#            red                                                            NaN
#            nir1                                                           NaN
#            nir2                                                           NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LT05_caea  blue                                                           NaN
#            green                                                          NaN
#            nir                                                            NaN
#            red                                                            NaN
#            swir1                                                          NaN
#            swir2                                                          NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# LT05_scene blue                                                           NaN
#            green                                                          NaN
#            nir                                                            NaN
#            red                                                            NaN
#            swir1                                                          NaN
#            swir2                                                          NaN
#            quality          {'cloud': {'bits': [4], 'values': {'0': False,...
#
#                                        name  nodata units
# product    measurement
# LC08_caea  coastal_aerosol  coastal_aerosol   -9999     1
#            blue                        blue   -9999     1
#            green                      green   -9999     1
#            red                          red   -9999     1
#            nir                          nir   -9999     1
#            swir1                      swir1   -9999     1
#            swir2                      swir2   -9999     1
#            panchromatic        panchromatic   -9999     1
#            cirrus                    cirrus   -9999     1
#            lwir1                      lwir1   -9999     1
#            lwir2                      lwir2   -9999     1
#            quality                  quality       0     1
# LC08_scene coastal_aerosol  coastal_aerosol   -9999     1
#            blue                        blue   -9999     1
#            green                      green   -9999     1
#            red                          red   -9999     1
#            nir                          nir   -9999     1
#            swir1                      swir1   -9999     1
#            swir2                      swir2   -9999     1
#            panchromatic        panchromatic   -9999     1
#            cirrus                    cirrus   -9999     1
#            lwir1                      lwir1   -9999     1
#            lwir2                      lwir2   -9999     1
#            quality                  quality       0     1
# LE07_caea  blue                        blue   -9999     1
#            green                      green   -9999     1
#            red                          red   -9999     1
#            nir                          nir   -9999     1
#            swir1                      swir1   -9999     1
#            swir2                      swir2   -9999     1
# ...                                     ...     ...   ...
# LM03_caea  quality                  quality       0     1
# LM03_scene green                      green   -9999     1
#            red                          red   -9999     1
#            nir1                        nir1   -9999     1
#            nir2                        nir2   -9999     1
#            quality                  quality       0     1
# LM05_caea  green                      green   -9999     1
#            red                          red   -9999     1
#            nir1                        nir1   -9999     1
#            nir2                        nir2   -9999     1
#            quality                  quality       0     1
# LM05_scene green                      green   -9999     1
#            red                          red   -9999     1
#            nir1                        nir1   -9999     1
#            nir2                        nir2   -9999     1
#            quality                  quality       0     1
# LT05_caea  blue                        blue   -9999     1
#            green                      green   -9999     1
#            nir                          nir   -9999     1
#            red                          red   -9999     1
#            swir1                      swir1   -9999     1
#            swir2                      swir2   -9999     1
#            quality                  quality       0     1
# LT05_scene blue                        blue   -9999     1
#            green                      green   -9999     1
#            nir                          nir   -9999     1
#            red                          red   -9999     1
#            swir1                      swir1   -9999     1
#            swir2                      swir2   -9999     1
#            quality                  quality       0     1
#
# [72 rows x 6 columns]
