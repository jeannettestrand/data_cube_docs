# %%
import datacube
dc = datacube.Datacube()
dc.list_products()
# Out:
#                             name  \
# id
# 22              ls5_ledaps_scene
# 18              ls5_level1_scene
# 3                ls5_level1_usgs
# 19                ls5_nbar_scene
# 20               ls5_nbart_scene
# 21                  ls5_pq_scene
# 17  ls5_satellite_telemetry_data
# 10              ls7_ledaps_scene
# 6               ls7_level1_scene
# 2                ls7_level1_usgs
# 7                 ls7_nbar_scene
# 8                ls7_nbart_scene
# 9                   ls7_pq_scene
# 5   ls7_satellite_telemetry_data
# 24             ls7_usgs_sr_scene
# 4                 ls8_l1_pc_usgs
# 16              ls8_ledaps_scene
# 12              ls8_level1_scene
# 1                ls8_level1_usgs
# 13                ls8_nbar_scene
# 14               ls8_nbart_scene
# 15                  ls8_pq_scene
# 11  ls8_satellite_telemetry_data
# 23             ls8_usgs_sr_scene
#
#                                           description  orbit  lon instrument  \
# id
# ...

# %%
dc.list_measurements()
# Out:
#                                                                      aliases  \
# product           measurement
# ls5_ledaps_scene  blue                                        [band_1, blue]
#                   green                                      [band_2, green]
#                   red                                          [band_3, red]
#                   nir                                          [band_4, nir]
#                   swir1                                      [band_5, swir1]
#                   swir2                                      [band_7, swir2]
#                   cfmask                                      [mask, CFmask]
#                   cfmask_conf                                  [mask_config]
#                   sr_adjacent_cloud_qa                      [adjacent_cloud]
#                   sr_atmos_opacity            [atmospheric_opacity, opacity]
#                   sr_cloud_qa                                        [cloud]
# ...

# %%
data = dc.load(product='ls8_level1_usgs')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-fd75dc5f9b49> in <module>()
# ----> 1 data = dc.load(product='ls8_level1_usgs')
#
# ~/miniconda3/envs/cubeenv/lib/python3.6/site-packages/datacube/api/core.py in load(self, product, measurements, output_crs, resolution, resampling, stack, dask_chunks, like, fuse_func, align, datasets, **query)
#     308                 grid_spec = self.index.products.get_by_name(product).grid_spec
#     309                 if not grid_spec or not grid_spec.crs:
# --> 310                     raise RuntimeError("Product has no default CRS. Must specify 'output_crs' and 'resolution'")
#     311                 crs = grid_spec.crs
#     312                 if not resolution:
#
# RuntimeError: Product has no default CRS. Must specify 'output_crs' and 'resolution'

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
